# %%
import numpy as np                               
import pandas as pd                              
import matplotlib.pyplot as plt                  
import seaborn as sns                            
# vectors 
# tables a
from dateutil.relativedelta import relativedelta # working 
from scipy.optimize import minimize              
import statsmodels.formula.api as smf            
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs

# %%
ads = pd.read_csv('C:\\Users\\risha\\Desktop\\Data Science Project\\ads.csv',  index_col=['Time'],parse_dates=['Time'])
ads
# Out:
#                         Ads
# Time
# 2017-09-13 00:00:00   80115
# 2017-09-13 01:00:00   79885
# 2017-09-13 02:00:00   89325
# 2017-09-13 03:00:00  101930
# 2017-09-13 04:00:00  121630
# ...                     ...
# 2017-09-21 19:00:00  155890
# 2017-09-21 20:00:00  123395
# 2017-09-21 21:00:00  103080
# 2017-09-21 22:00:00   95155
# 2017-09-21 23:00:00   80285
#
# [216 rows x 1 columns]

# %%
currency = pd.read_csv('C:\\Users\\risha\\Desktop\\Data Science Project\\currency.csv', index_col=['Time'], parse_dates=['Time'])
currency
# Out:
# C:\Users\risha\AppData\Local\Temp\ipykernel_7360\371101553.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   currency = pd.read_csv('C:\\Users\\risha\\Desktop\\Data Science Project\\currency.csv', index_col=['Time'], parse_dates=['Time'])
#             GEMS_GEMS_SPENT
# Time
# 2017-05-01          1199436
# 2017-05-02          1045515
# 2017-05-03           586111
# 2017-05-04           856601
# 2017-05-05           793775
# ...                     ...
# 2018-02-20          2166449
# 2018-02-21          1552313
# 2018-02-22          2175548
# 2018-02-23          2122606
# 2018-02-24          1756394
#
# [300 rows x 1 columns]

# %%
plt.figure(figsize=(15, 7))
plt.plot(ads.Ads)
plt.title('Ads watched (hourly data)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(currency.GEMS_GEMS_SPENT)
plt.title('In-game currency spent (daily data)')
plt.grid(True)
plt.show()

# %%
def moving_average(series, n):
    """
        Calculate average of last n observations
    """
    return np.average(series[-n:])

moving_average(ads, 24) # prediction for the last observed day (past 24 hours)
# Out:
# 116805.0
